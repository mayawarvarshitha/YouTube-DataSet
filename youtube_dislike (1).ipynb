# %%
import pandas as pd

# %%
dt = pd.read_csv('/content/drive/MyDrive/youtube_dislike_dataset (3).csv')

# %%
dt
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
#1.Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top5 and bottom 5 records
dt.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
dt.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %%
#2)Check the info of the dataframe and write your inferences on data types and shape of the dataset.
dt.info()
#Datatypes mainly contains two types they are:
#i) integer:This data type is used for numerical data. This data type include 'view_count', 'likes', 'dislikes', and 'comment_count.
#ii) object:This data type is used for categorical data.This data type include 'video_id', 'title', 'channel_id', 'channel_title', 'published_at', 'tags', 'description', and 'comments'.

#Shape of the data set.
#The Dataset has 37,422 rows.
#It consists of 12 columns.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
#3)Check for the Percentage of the missing values and drop or impute them.
dt.isnull().sum()
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %%
((158*100)/37422)
# Out:
# 0.42221153332264444

# %%
dt.drop(['comments'],axis=1,inplace=True)

# %%
#4)Check the statistical summary of both numerical and categorical columns and write your inferences.
dt.describe()
#The describe method provides statistics such as count, mean, standard deviation, minimum, and maximum for numerical columns.
#Numerical Columns:
#statistics like count, mean, standard deviation, minimum, and maximum for numerical columns like 'view_count', 'likes', 'dislikes', and 'comment_count'.
#These statistics will give overview of the central tendency, spread, and range of the numerical data.
#categorical columns:
#Dataset doesn't contain categorical columns
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
#5)Convert datatype of column published_at from object to pandas datetime.
import datetime as dt

# %%
dt['published_at'] = pd.to_datetime(dt['published_at'])

# %%
dt.dtypes
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at     datetime64[ns]
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# dtype: object

# %%
#6)Create a new column as 'published_month' using the column published_at (display the months only)
dt['published_month']=dt['published_at'].dt.month

# %%
dt
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
#7) Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'and so on....
dt['published_month'].replace({1:"Jan",2:"Feb",3:"Mar",4:"Apr",5:"May",6:"Jun",7:"Jul",8:"Aug",9:"Sep",10:"Oct",11:"Nov",12:" Dec"},inplace=True)

# %%
dt
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
#8)8. Find the number of videos published each month and arrange the months in a decreasing order basedon the video count
data = dt.groupby('published_month').count().sort_values(by = 'video_id',ascending= False)

# %%
data
# Out:
#                  video_id  title  channel_id  channel_title  published_at  \
# published_month
# Oct                  4991   4991        4991           4991          4991
# Sep                  4880   4880        4880           4880          4880
# Nov                  4851   4851        4851           4851          4851
# Aug                  4262   4262        4262           4262          4262
#  Dec                 3072   3072        3072           3072          3072
# Jul                  2340   2340        2340           2340          2340
# Jun                  2316   2316        2316           2316          2316
# Mar                  2258   2258        2258           2258          2258
# Feb                  2137   2137        2137           2137          2137
# Apr                  2126   2126        2126           2126          2126
# Jan                  2108   2108        2108           2108          2108
# ...

# %%
#9) Find the count of unique video_id, channel_id and channel_title
dt['video_id'].nunique()
# Out:
# 37422

# %%
dt['channel_id'].nunique()
# Out:
# 10961

# %%
dt['channel_title'].nunique()
# Out:
# 10883

# %%
#10)10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10
 having lowest number of videos
df = dt.groupby('channel_title').count().sort_values(by = 'video_id',ascending= False)

# %%
df
# Out:
#                      video_id  title  channel_id  published_at  view_count  \
# channel_title
# Sky Sports Football       533    533         533           533         533
# The United Stand          301    301         301           301         301
# BT Sport                  246    246         246           246         246
# NBA                       209    209         209           209         209
# NFL                       162    162         162           162         162
# ...                       ...    ...         ...           ...         ...
# Kannada Cinema              1      1           1             1           1
# KanalD                      1      1           1             1           1
# Kanak News                  1      1           1             1           1
# Kamille Ramos               1      1           1             1           1
# zoom                        1      1           1             1           1
#
# ...

# %%
df.head(10)
# Out:
#                      video_id  title  channel_id  published_at  view_count  \
# channel_title
# Sky Sports Football       533    533         533           533         533
# The United Stand          301    301         301           301         301
# BT Sport                  246    246         246           246         246
# NBA                       209    209         209           209         209
# NFL                       162    162         162           162         162
# WWE                       122    122         122           122         122
# SSSniperWolf               99     99          99            99          99
# SSundee                    98     98          98            98          98
# FORMULA 1                  87     87          87            87          87
# NHL                        86     86          86            86          86
#
#                      likes  dislikes  comment_count  tags  description  \
# channel_title
# ...

# %%
df.tail(10)
# Out:
#                 video_id  title  channel_id  published_at  view_count  likes  \
# channel_title
# Karchez                1      1           1             1           1      1
# Karate Combat          1      1           1             1           1      1
# Kaptain Kuba           1      1           1             1           1      1
# Kanye West             1      1           1             1           1      1
# Kannur kitchen         1      1           1             1           1      1
# Kannada Cinema         1      1           1             1           1      1
# KanalD                 1      1           1             1           1      1
# Kanak News             1      1           1             1           1      1
# Kamille Ramos          1      1           1             1           1      1
# zoom                   1      1           1             1           1      1
#
#                 dislikes  comment_count  tags  description  published_month
# channel_title
# ...

# %%
#11)Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.
dt.groupby('title').sum().sort_values(by = 'likes',ascending= False)
#inferences
#we have maximum likes (BTS () 'Dynamite' Official MV)
#we have minimum likes (Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News)
# Out:
# <ipython-input-34-0bf0c17fe927>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dt.groupby('title').sum().sort_values(by = 'likes',ascending= False)
#                                                     view_count     likes  \
# title
# BTS () 'Dynamite' Official MV                       1322796924  31837675
# BTS () 'Butter' Official MV                          638732230  20649409
# BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V      671712535  17864527
# BTS () 'Life Goes On' Official MV                    412591136  16354127
# BTS () 'Permission to Dance' Official MV             392440299  15449003
# ...                                                        ...       ...
# Virtual Pub Quiz, Live! Saturday 12th December           39467        97
# ...

# %%
#12)Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences
dt.groupby('title').sum().sort_values(by = 'dislikes',ascending= False)
#inferences
#we have the maximum dislikes ( Cuties | Official Trailer | Netflix )
#we have the minimum  dislikes (Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News)
# Out:
# <ipython-input-35-247f74ce18cf>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dt.groupby('title').sum().sort_values(by = 'dislikes',ascending= False)
#                                                     view_count     likes  \
# title
# Cuties | Official Trailer | Netflix                   17996395     94569
# BTS () 'Dynamite' Official MV                       1322796924  31837675
# Cardi B - WAP feat. Megan Thee Stallion [Offici...   432214292   8140694
# 52 GAJ KA DAMAN | PRANJAL DAHIYA | AMAN JAJI | ...  1269596718   6326231
# BLACKPINK - 'Ice Cream (with Selena Gomez)' M/V      671712535  17864527
# ...                                                        ...       ...
# YONEX Thailand Open | Day 3: Saina Nehwal (IND)...       56768       152
# ...

# %%
#13)Does the number of views have any effect on how many people disliked the video? Support you answer with a metric and a plot.
import seaborn as sns

# %%
dt.corr()
#view_counts are effecting on dislikes
# Out:
# <ipython-input-44-17565431b9e9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dt.corr()
#                view_count     likes  dislikes  comment_count
# view_count       1.000000  0.784229  0.684469       0.464392
# likes            0.784229  1.000000  0.679817       0.580953
# dislikes         0.684469  0.679817  1.000000       0.391739
# comment_count    0.464392  0.580953  0.391739       1.000000

# %%
sns.scatterplot(x='view_count',y='dislikes',data=dt)
# Out:
# <Axes: xlabel='view_count', ylabel='dislikes'>

# %%
#14)Display all the information about the videos that were published in January, and mention the count of videos that were published in January.
Jan_dt=dt[dt['published_month']=='Jan']

# %%
Jan_dt
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
len(Jan_dt['video_id'])
# Out:
# 2108
